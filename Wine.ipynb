# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
train = pd.read_csv("C:/Users/162322/data/train.csv", encoding="utf-8")
test = pd.read_csv("C:/Users/162322/data/test.csv", encoding="utf-8")
sub = pd.read_csv("C:/Users/162322/data/sample_submission.csv", encoding="utf-8")

# %%
train
# Out:
#       index  quality  fixed acidity  volatile acidity  citric acid  \
# 0         0        5            5.6             0.695         0.06
# 1         1        5            8.8             0.610         0.14
# 2         2        5            7.9             0.210         0.39
# 3         3        6            7.0             0.210         0.31
# 4         4        6            7.8             0.400         0.26
# ...     ...      ...            ...               ...          ...
# 5492   5492        5            7.7             0.150         0.29
# 5493   5493        6            6.3             0.180         0.36
# 5494   5494        7            7.8             0.150         0.34
# 5495   5495        5            6.6             0.410         0.31
# 5496   5496        6            7.0             0.350         0.17
#
#       residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0                6.8      0.042                  9.0                  84.0
# ...

# %%
# train 데이터의 열 별 정보를 살펴봅니다. 
# 결측치는 없습니다.
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5497 entries, 0 to 5496
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   index                 5497 non-null   int64
#  1   quality               5497 non-null   int64
#  2   fixed acidity         5497 non-null   float64
#  3   volatile acidity      5497 non-null   float64
#  4   citric acid           5497 non-null   float64
#  5   residual sugar        5497 non-null   float64
#  6   chlorides             5497 non-null   float64
#  7   free sulfur dioxide   5497 non-null   float64
#  8   total sulfur dioxide  5497 non-null   float64
#  9   density               5497 non-null   float64
#  10  pH                    5497 non-null   float64
#  11  sulphates             5497 non-null   float64
#  12  alcohol               5497 non-null   float64
#  13  type                  5497 non-null   object
# dtypes: float64(11), int64(2), object(1)
# ...

# %%
# train의 변수 간 상관관계를 살펴봅니다.
plt.figure(figsize=(12,12))
sns.heatmap(data = train.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# test의 변수 간 상관관계를 살펴봅니다.
plt.figure(figsize=(12,12))
sns.heatmap(data = test.corr(), annot=True, fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# train의 각 변수별 분포를 살펴봅니다. 
plt.figure(figsize=(12,12))
for i in range(1,13):
    plt.subplot(3,4,i)
    sns.distplot(train.iloc[:,i])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\162322\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\162322\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# test의 각 변수별 분포를 살펴봅니다. 
plt.figure(figsize=(12,12))
for i in range(1,12):
    plt.subplot(3,4,i)
    sns.distplot(test.iloc[:,i])
plt.tight_layout()
plt.show()
# Out:
# C:\Users\162322\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\162322\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# train에서 각 변수와 quality 변수 사이 분포를 확인합니다.
for i in range(11):
    fig = plt.figure(figsize = (12,6))
    sns.barplot(x = 'quality', y = train.columns[i+2], data = train)

# %%
import pandas as pd
import lightgbm as lgbm

# %%
# type에는 white와 red 두 종류가 있습니다.
# 각각 0,1로 변환합니다.
train['type'] = train['type'].map({'white':0, 'red':1}).astype(int)
test['type'] = test['type'].map({'white':0, 'red':1}).astype(int)

# %%
train.head()
# Out:
#    index  quality  fixed acidity  volatile acidity  citric acid  \
# 0      0        5            5.6             0.695         0.06
# 1      1        5            8.8             0.610         0.14
# 2      2        5            7.9             0.210         0.39
# 3      3        6            7.0             0.210         0.31
# 4      4        6            7.8             0.400         0.26
#
#    residual sugar  chlorides  free sulfur dioxide  total sulfur dioxide  \
# 0             6.8      0.042                  9.0                  84.0
# 1             2.4      0.067                 10.0                  42.0
# 2             2.0      0.057                 21.0                 138.0
# 3             6.0      0.046                 29.0                 108.0
# 4             9.5      0.059                 32.0                 178.0
#
#    density    pH  sulphates  alcohol  type
# 0  0.99432  3.44       0.44     10.2     0
# 1  0.99690  3.19       0.59      9.5     1
# ...

# %%
# 모델에 입력하기 전 데이터를 정형합니다.
train_x = train.drop(['index', 'quality'], axis = 1)
train_y = train['quality']
test_x = test.drop('index', axis = 1)

# %%
train_x.shape, train_y.shape, test_x.shape
# Out:
# ((5497, 12), (5497,), (1000, 12))

# %%
model = lgbm.LGBMClassifier()
model.fit(train_x,train_y)
# Out:
# LGBMClassifier()

# %%
preds = model.predict(test_x)
sub.iloc[:,1] = preds.round()
sub.to_csv('wine.csv', index=False)

# %% [markdown]
# # 검증

# %%
# 1. 학습/검증 데이터 분리 (분리 비율 8:2)
from sklearn.model_selection import train_test_split
train_X, val_X, train_y, val_y = train_test_split(train_x, train_y,random_state = 4321, test_size = 0.2)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
params = {'max_depth': [10, 15, 20],
          'min_child_samples': [20, 40, 60],
          'subsample': [0.8, 1]}

# %%
grid = GridSearchCV(lgbm, param_grid=params)
grid.fit(train_X, train_y, early_stopping_rounds=100, eval_metric='auc',
         eval_set=[(train_X, train_y), (val_X, val_y)])

print("최적 파라미터: ", grid.best_params_)
lgbm_roc_score = roc_auc_score(Y_test, grid.predict_proba(X_test)[:, 1], average='macro')
print("ROC AUC: {0:.4f}".format(lgbm_roc_score))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12780/275218076.py in <module>
#       1 grid = GridSearchCV(lgbm, param_grid=params)
# ----> 2 grid.fit(train_X, train_y, early_stopping_rounds=100, eval_metric='auc',
#       3          eval_set=[(train_X, train_y), (val_X, val_y)])
#       4
#       5 print("최적 파라미터: ", grid.best_params_)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     751             scorers = self.scoring
# ...

# %%
# 2. 하이퍼파라미터 테스트 (모델 : RandomForst, 하이퍼파라미터 : max_leaf_nodes)
from sklearn.metrics import mean_squared_error

# max_depth, num_leaves, min_child_samples, sub_sample

def get_mse(n_estimators, max_leaf_nodes, max_depth, train_X, val_X, train_y, val_y):
    model = lgbm.LGBMClassifier()
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mse = mean_squared_error(val_y, preds_val)
    return(mse)

best_param_err = [[0,0,0],100] # 최적의 하이퍼 파라미터의 순서쌍과 에러를 저장 

for max_leaf_nodes in [5, 50, 100, 80, 90, 500, 5000]: #이곳에 찾고자 하는 max_leaf_nodes 조합을 넣어주세요
    for n_estimators in [5,10,50,100,500] : #이곳에 찾고자 하는 n_estimators 조합을 넣어주세요
        for max_depth in [1,3,5,7,9,30,50,100] : #이곳에 찾고자 하는 max_depth의 조합을 넣어주세요
            my_mae = get_mae(n_estimators, max_leaf_nodes, max_depth, train_X, val_X, train_y, val_y)
            if best_param_err[1] > my_mae : # 에러값이 더 낮게 나오면
                best_param_err[0] = [n_estimators, max_leaf_nodes, max_depth] # 순서쌍 갱신
                best_param_err[1] = my_mae # 에러 갱신
            print("n_estimators : %d \t\t Max leaf nodes : %d  \t\t max_depth : %d  \t\t Mean Absolute Error:  %f" %(n_estimators, max_leaf_nodes, max_depth, my_mae)) # Mean Absolute Error 값이 가장 낮게 나오는 값을 선택
            
best_param_err # 최적의 순서쌍, 에러

# %%
# !pip install catboost

# %%
y_pred = model.predict(test_x)

# %%
y_pred

# %%
smpl_sub = pd.DataFrame()
#서브미션 파일의 quality 변수에 예측값을 대입합니다.
smpl_sub['index'] = test['index']
smpl_sub['quality'] = y_pred

# %%
smpl_sub

# %%
# csv 파일로 저장합니다.
smpl_sub.to_csv('submission.csv', index=False)
